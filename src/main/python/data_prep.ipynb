# %%
import os
import json
from pandas.io.json import json_normalize
from helpers.paths import DATA_PATH

# Generalized path names 
MAIN_ROOT = os.path.dirname(os.path.dirname(os.path.realpath('__file__')))
DATA_PATH = os.path.join(MAIN_ROOT, 'data')

# Build the full path from the data directory
dataset_name = '/champions.json'
full_path = DATA_PATH + dataset_name
    
# Load json object
with open(full_path) as f:
    d = json.load(f)

#d

# %%
# Test Flatten   
result = json_normalize(d['data'])
result # this  did not work, lol
# Out:
#                                         Aatrox.blurb Aatrox.id  \
# 0  Aatrox is a legendary warrior, one of only fiv...    Aatrox
#
#   Aatrox.image.full Aatrox.image.group  Aatrox.image.h Aatrox.image.sprite  \
# 0        Aatrox.png           champion              48       champion0.png
#
#    Aatrox.image.w  Aatrox.image.x  Aatrox.image.y  Aatrox.info.attack  \
# 0              48               0               0                   8
#
#        ...       Zyra.stats.movespeed  Zyra.stats.mp  Zyra.stats.mpperlevel  \
# 0      ...                      340.0          334.0                   50.0
#
#   Zyra.stats.mpregen Zyra.stats.mpregenperlevel Zyra.stats.spellblock  \
# 0                8.5                        0.8                  30.0
#
#    Zyra.stats.spellblockperlevel        Zyra.tags          Zyra.title  \
# 0                            0.0  [Mage, Support]  Rise of the Thorns
#
#    Zyra.version
# 0        6.24.1
#
# [1 rows x 5226 columns]

# %%
import pandas as pd

df = pd.DataFrame.from_dict(d)
print(df['data']['Aatrox']['stats'].keys())
df.head()
# Out:
# dict_keys(['hp', 'hpperlevel', 'mp', 'mpperlevel', 'movespeed', 'armor', 'armorperlevel', 'spellblock', 'spellblockperlevel', 'attackrange', 'hpregen', 'hpregenperlevel', 'mpregen', 'mpregenperlevel', 'crit', 'critperlevel', 'attackdamage', 'attackdamageperlevel', 'attackspeedoffset', 'attackspeedperlevel'])
#              type             format version  \
# Aatrox   champion  standAloneComplex  6.24.1
# Ahri     champion  standAloneComplex  6.24.1
# Akali    champion  standAloneComplex  6.24.1
# Alistar  champion  standAloneComplex  6.24.1
# Amumu    champion  standAloneComplex  6.24.1
#
#                                                       data
# Aatrox   {'version': '6.24.1', 'id': 'Aatrox', 'key': '...
# Ahri     {'version': '6.24.1', 'id': 'Ahri', 'key': '10...
# Akali    {'version': '6.24.1', 'id': 'Akali', 'key': '8...
# Alistar  {'version': '6.24.1', 'id': 'Alistar', 'key': ...
# Amumu    {'version': '6.24.1', 'id': 'Amumu', 'key': '3...

# %%
#  This is closer. Need to flatten out the nested JSON lists for info, image, and stats:

#info: ['attack', 'defense', 'magic', 'difficulty']
#image: ['full', 'sprite', 'group', 'x', 'y', 'w', 'h']
#stats: ['hp', 'hpperlevel', 'mp', 'mpperlevel', 'movespeed', 'armor', 'armorperlevel', 'spellblock',
#'spellblockperlevel', 'attackrange', 'hpregen', 'hpregenperlevel', 'mpregen', 'mpregenperlevel', 'crit',
#'critperlevel', 'attackdamage', 'attackdamageperlevel', 'attackspeedoffset', 'attackspeedperlevel']

df = df['data'].apply(pd.Series).reset_index()
df.head()
# Out:
#      index version       id  key     name                title  \
# 0   Aatrox  6.24.1   Aatrox  266   Aatrox     the Darkin Blade
# 1     Ahri  6.24.1     Ahri  103     Ahri  the Nine-Tailed Fox
# 2    Akali  6.24.1    Akali   84    Akali   the Fist of Shadow
# 3  Alistar  6.24.1  Alistar   12  Alistar         the Minotaur
# 4    Amumu  6.24.1    Amumu   32    Amumu        the Sad Mummy
#
#                                                blurb  \
# 0  Aatrox is a legendary warrior, one of only fiv...
# 1  Unlike other foxes that roamed the woods of so...
# 2  There exists an ancient order originating in t...
# 3  As the mightiest warrior to ever emerge from t...
# 4  ''Solitude can be lonelier than death.''<br><b...
#
#                                                 info  \
# 0  {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# 1  {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
# 2  {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
# 3  {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
# 4  {'attack': 2, 'defense': 6, 'magic': 8, 'diffi...
#
#                                                image              tags  \
# 0  {'full': 'Aatrox.png', 'sprite': 'champion0.pn...   [Fighter, Tank]
# 1  {'full': 'Ahri.png', 'sprite': 'champion0.png'...  [Mage, Assassin]
# 2  {'full': 'Akali.png', 'sprite': 'champion0.png...        [Assassin]
# 3  {'full': 'Alistar.png', 'sprite': 'champion0.p...   [Tank, Support]
# 4  {'full': 'Amumu.png', 'sprite': 'champion0.png...      [Tank, Mage]
#
#      partype                                              stats
# 0  BloodWell  {'hp': 537.8, 'hpperlevel': 85.0, 'mp': 105.6,...
# 1         MP  {'hp': 514.4, 'hpperlevel': 80.0, 'mp': 334.0,...
# 2     Energy  {'hp': 587.8, 'hpperlevel': 85.0, 'mp': 200.0,...
# 3         MP  {'hp': 613.36, 'hpperlevel': 106.0, 'mp': 278....
# 4         MP  {'hp': 613.12, 'hpperlevel': 84.0, 'mp': 287.2...

# %%
norm_info = json_normalize(df['info']).add_prefix('info.')
norm_image = json_normalize(df['image']).add_prefix('image.')
norm_stats = json_normalize(df['stats']).add_prefix('stats.')
norm_stats.head()
# Out:
#    stats.armor  stats.armorperlevel  stats.attackdamage  \
# 0       24.384                  3.8             60.3760
# 1       20.880                  3.5             53.0400
# 2       26.380                  3.5             58.3760
# 3       24.380                  3.5             61.1116
# 4       23.544                  3.8             53.3840
#
#    stats.attackdamageperlevel  stats.attackrange  stats.attackspeedoffset  \
# 0                        3.20              150.0                   -0.040
# 1                        3.00              550.0                   -0.065
# 2                        3.20              125.0                   -0.100
# 3                        3.62              125.0                    0.000
# 4                        3.80              125.0                   -0.020
#
#    stats.attackspeedperlevel  stats.crit  stats.critperlevel  stats.hp  \
# 0                      3.000         0.0                 0.0    537.80
# 1                      2.000         0.0                 0.0    514.40
# 2                      3.100         0.0                 0.0    587.80
# 3                      2.125         0.0                 0.0    613.36
# 4                      2.180         0.0                 0.0    613.12
#
#    stats.hpperlevel  stats.hpregen  stats.hpregenperlevel  stats.movespeed  \
# 0              85.0          6.590                   0.50            345.0
# 1              80.0          6.505                   0.60            330.0
# 2              85.0          8.340                   0.65            350.0
# 3             106.0          8.675                   0.85            330.0
# 4              84.0          8.875                   0.85            335.0
#
#    stats.mp  stats.mpperlevel  stats.mpregen  stats.mpregenperlevel  \
# 0    105.60              45.0           0.00                  0.000
# 1    334.00              50.0           6.00                  0.800
# 2    200.00               0.0          50.00                  0.000
# 3    278.84              38.0           8.50                  0.800
# 4    287.20              40.0           7.38                  0.525
#
#    stats.spellblock  stats.spellblockperlevel
# 0              32.1                      1.25
# 1              30.0                      0.00
# 2              32.1                      1.25
# 3              32.1                      1.25
# 4              32.1                      1.25

# %%
norm_df = pd.concat([df.drop('info', axis=1), df.join(norm_info)], axis=1)
norm_df = pd.concat([norm_df.drop('image', axis=1), norm_df.join(norm_image)], axis=1)
norm_df = pd.concat([norm_df.drop('stats', axis=1), norm_df.join(norm_stats)], axis=1)
norm_df.head()
# Out:
#      index version       id  key     name                title  \
# 0   Aatrox  6.24.1   Aatrox  266   Aatrox     the Darkin Blade
# 1     Ahri  6.24.1     Ahri  103     Ahri  the Nine-Tailed Fox
# 2    Akali  6.24.1    Akali   84    Akali   the Fist of Shadow
# 3  Alistar  6.24.1  Alistar   12  Alistar         the Minotaur
# 4    Amumu  6.24.1    Amumu   32    Amumu        the Sad Mummy
#
#                                                blurb              tags  \
# 0  Aatrox is a legendary warrior, one of only fiv...   [Fighter, Tank]
# 1  Unlike other foxes that roamed the woods of so...  [Mage, Assassin]
# 2  There exists an ancient order originating in t...        [Assassin]
# 3  As the mightiest warrior to ever emerge from t...   [Tank, Support]
# 4  ''Solitude can be lonelier than death.''<br><b...      [Tank, Mage]
#
#      partype  attack           ...             stats.hpperlevel  \
# 0  BloodWell       8           ...                         85.0
# 1         MP       3           ...                         80.0
# 2     Energy       5           ...                         85.0
# 3         MP       6           ...                        106.0
# 4         MP       2           ...                         84.0
#
#    stats.hpregen  stats.hpregenperlevel stats.movespeed stats.mp  \
# 0          6.590                   0.50           345.0   105.60
# 1          6.505                   0.60           330.0   334.00
# 2          8.340                   0.65           350.0   200.00
# 3          8.675                   0.85           330.0   278.84
# 4          8.875                   0.85           335.0   287.20
#
#   stats.mpperlevel stats.mpregen stats.mpregenperlevel stats.spellblock  \
# 0             45.0          0.00                 0.000             32.1
# 1             50.0          6.00                 0.800             30.0
# 2              0.0         50.00                 0.000             32.1
# 3             38.0          8.50                 0.800             32.1
# 4             40.0          7.38                 0.525             32.1
#
#   stats.spellblockperlevel
# 0                     1.25
# 1                     0.00
# 2                     1.25
# 3                     1.25
# 4                     1.25
#
# [5 rows x 166 columns]

# %%
norm_df = norm_df.drop(['index', 'id'], axis=1)
norm_df.head()
# Out:
#   version  key     name                title  \
# 0  6.24.1  266   Aatrox     the Darkin Blade
# 1  6.24.1  103     Ahri  the Nine-Tailed Fox
# 2  6.24.1   84    Akali   the Fist of Shadow
# 3  6.24.1   12  Alistar         the Minotaur
# 4  6.24.1   32    Amumu        the Sad Mummy
#
#                                                blurb              tags  \
# 0  Aatrox is a legendary warrior, one of only fiv...   [Fighter, Tank]
# 1  Unlike other foxes that roamed the woods of so...  [Mage, Assassin]
# 2  There exists an ancient order originating in t...        [Assassin]
# 3  As the mightiest warrior to ever emerge from t...   [Tank, Support]
# 4  ''Solitude can be lonelier than death.''<br><b...      [Tank, Mage]
#
#      partype  attack  defense  difficulty            ...             \
# 0  BloodWell       8        4           4            ...
# 1         MP       3        4           5            ...
# 2     Energy       5        3           7            ...
# 3         MP       6        9           7            ...
# 4         MP       2        6           3            ...
#
#    stats.hpperlevel stats.hpregen stats.hpregenperlevel stats.movespeed  \
# 0              85.0         6.590                  0.50           345.0
# 1              80.0         6.505                  0.60           330.0
# 2              85.0         8.340                  0.65           350.0
# 3             106.0         8.675                  0.85           330.0
# 4              84.0         8.875                  0.85           335.0
#
#   stats.mp stats.mpperlevel stats.mpregen stats.mpregenperlevel  \
# 0   105.60             45.0          0.00                 0.000
# 1   334.00             50.0          6.00                 0.800
# 2   200.00              0.0         50.00                 0.000
# 3   278.84             38.0          8.50                 0.800
# 4   287.20             40.0          7.38                 0.525
#
#   stats.spellblock  stats.spellblockperlevel
# 0             32.1                      1.25
# 1             30.0                      0.00
# 2             32.1                      1.25
# 3             32.1                      1.25
# 4             32.1                      1.25
#
# [5 rows x 150 columns]

# %% [markdown]
# ## Other things I tried

# %%
result = json_normalize(data = df, record_path = 'info', 
                        errors='ignore', meta=['attack', 'defense', 'magic', 'difficulty'])
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-bdcf9d67c3e1> in <module>()
#       1 result = json_normalize(data = df, record_path = 'info',
# ----> 2                         errors='ignore', meta=['attack', 'defense', 'magic', 'difficulty'])
#       3 result
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/json/normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     257                 records.extend(recs)
#     258
# --> 259     _recursive_extract(data, record_path, {}, level=0)
#     260
#     261     result = DataFrame(records)
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/json/normalize.py in _recursive_extract(data, path, seen_meta, level)
#     233         else:
#     234             for obj in data:
# --> 235                 recs = _pull_field(obj, path[0])
#     236
#     237                 # For repeating the metadata later
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/json/normalize.py in _pull_field(js, spec)
#     180                 result = result[field]
#     181         else:
# --> 182             result = result[spec]
#     183
#     184         return result
#
# TypeError: string indices must be integers

# %% [markdown]
# ## Flatten
# This would have been cool to get working

# %%
result = json_normalize(data = d, record_path = 'data', errors='ignore',#meta_prefix="champion-",
                        meta=['version', 'id', 'key', 'name', 'title', 'blurb', 'info', 'image', 'tags', 'partype', 'stats'])
result.head()
# Out:
#          0 version  id  key  name  title  blurb  info  image  tags  partype  \
# 0   Aatrox  6.24.1 NaN  NaN   NaN    NaN    NaN   NaN    NaN   NaN      NaN
# 1     Ahri  6.24.1 NaN  NaN   NaN    NaN    NaN   NaN    NaN   NaN      NaN
# 2    Akali  6.24.1 NaN  NaN   NaN    NaN    NaN   NaN    NaN   NaN      NaN
# 3  Alistar  6.24.1 NaN  NaN   NaN    NaN    NaN   NaN    NaN   NaN      NaN
# 4    Amumu  6.24.1 NaN  NaN   NaN    NaN    NaN   NaN    NaN   NaN      NaN
#
#    stats
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
d['data']['Aatrox'].keys()
# Out:
# dict_keys(['version', 'id', 'key', 'name', 'title', 'blurb', 'info', 'image', 'tags', 'partype', 'stats'])
